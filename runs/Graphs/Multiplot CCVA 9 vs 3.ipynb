# %%
import numpy as np

# %%
CVA9 = np.array([18.48, 14.74, 12.95, 11.60, 10.37, 9.15, 7.86, 6.42, 4.64, 3.70, 2.36, 1.03, 0.53])
DVA9 = np.array([1.03, 1.06, 1.00, 0.90, 0.79, 0.66, 0.53, 0.38, 0.22, 0.15, 0.07, 0.03, 0.02])
KVA9 = np.array([27.48, 19.22, 14.85, 11.58, 8.88, 6.55, 4.51, 2.72, 1.19, 0.66, 0.19, 0.02, 0.00])
MLA9 = np.array([1.11, 1.05, 1.12, 1.22, 1.36, 1.54, 1.76, 2.07, 2.56, 2.90, 3.56, 4.72, 5.70])
MVA9 = np.array([0.66, 1.04, 1.44, 1.86, 2.32, 2.83, 3.43, 4.19, 5.32, 6.06, 7.47, 9.92, 11.98])

FVA9 = MLA9 + MVA9

# %%
CVA3 = np.array([9.09, 7.71, 7.20, 6.81, 6.39, 5.89, 5.26, 4.45, 3.31, 2.66, 1.67, 0.67, 0.35])
DVA3 = np.array([-0.51, -0.63, -0.65, -0.64, -0.60, -0.54, -0.45, -0.35, -0.21, -0.15, -0.07, -0.03, -0.02])
KVA3 = np.array([56.40, 40.25, 31.34, 24.56, 18.88, 13.95, 9.62, 5.82, 2.56, 1.42, 0.41, 0.03, 0.00])
MLA3 = np.array([1.98, 1.68, 1.61, 1.61, 1.66, 1.76, 1.91, 2.16, 2.60, 2.92, 3.56, 4.72, 5.70])
MVA3 = np.array([0.66, 1.04, 1.44, 1.86, 2.32, 2.83, 3.43, 4.19, 5.32, 6.06, 7.47, 9.92, 11.98])

FVA3 = MLA3 + MVA3

# %%
quantile_levels = [0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.97, 0.99, 0.999, 0.9999]

# %%
from matplotlib.ticker import FuncFormatter

formatter_pct = FuncFormatter(lambda y, pos: "%.0f %%" % (100 * y))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_context('talk')
sns.set_style("whitegrid")
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
fig, ax = plt.subplots(1)

ax.plot(quantile_levels, CVA9, "p:", label='CVA')
ax.plot(quantile_levels, FVA9, "p:", label='FVA')
ax.plot(quantile_levels, KVA9, "p:", label='KVA')
    
handles, labels = ax.get_legend_handles_labels()

# reverse the order
#ax.legend([handles[0], handles[2], handles[1]], [labels[0], labels[2], labels[1]], loc='best')
ax.legend(loc='best')

ax.set_xlabel(r'$a$')
ax.xaxis.set_major_formatter(formatter_pct)

ax.set_ylabel(r'$XVA \, \, (bp)$', rotation='horizontal')
ax.yaxis.set_label_coords(-0.1, +0.5)

plt.show()

# %%
fig, ax = plt.subplots(1)

ax.plot(quantile_levels, CVA3, "p:", label='CVA')
ax.plot(quantile_levels, FVA3, "p:", label='FVA')
ax.plot(quantile_levels, KVA3, "p:", label='KVA')
    
handles, labels = ax.get_legend_handles_labels()

# reverse the order
#ax.legend(handles[::-1], labels[::-1], loc='upper left')
ax.legend(loc='best')

ax.set_xlabel(r'$a$')
ax.xaxis.set_major_formatter(formatter_pct)

ax.set_ylabel(r'$XVA \, \, (bp)$', rotation='horizontal')
ax.yaxis.set_label_coords(-0.1, +0.5)

plt.show()
